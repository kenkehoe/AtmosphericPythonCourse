# %% [markdown]
# ## Working with Pandas
# Pandas is an extension of the Numpy data model to structure and organize data into Dataframes. A Dataframe resembles a spreadsheet in looks, but is much more powerful.

# %%
import pandas as pd  # Convention suggest to import as pd

from pathlib import Path  # Importing a sub-module of the pathlib library
import numpy as np  # Our old friend Numpy

# %% [markdown]
# ## Create Pandas Dataframe
# Create some data in a Python dictionary

# %%
data = {'apples': [3, 2, 0, 1],
        'oranges': [0, 3, 7, 2]}
data
# Out:
# {'apples': [3, 2, 0, 1], 'oranges': [0, 3, 7, 2]}

# %% [markdown]
# Use the dictionary to populate the new pandas data frame. Python and Jupyter play very well with Pandas and when requested to print the _Pandas_ _Dataframe_ or _Series_ Jupyter knows how to print in a visually appealing way. Notice the columns have names taken from the Dictionary keys we used to populate the Dataframe. Each row has an index set to an incremented integer by default.

# %%
purchases = pd.DataFrame(data)
purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %% [markdown]
# Pandas DataFrame consisting of Series

# %%
type(purchases)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Print the data type of the Pandas Series

# %%
type(purchases.apples)
# Out:
# pandas.core.series.Series

# %% [markdown]
# A Dataframe has a concept of _index_ to label the rows of the Dataframe and column names to label the Columns. We created column names from the Dictionary keys used to initially create the Dataframe.

# %%
purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])
purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %% [markdown]
# Printing the column shows additional informatin including the index and data type.

# %%
purchases.apples
# Out:
# June      3
# Robert    2
# Lily      0
# David     1
# Name: apples, dtype: int64

# %% [markdown]
# Extracting a row uses the .loc() method on the Dataframe. .loc() standar for location and searches the index for a match.

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %% [markdown]
# Can also extract using numeric index location .iloc() method.

# %%
purchases.iloc[0]
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %% [markdown]
# ## Read in some data
# Using the path to a specific file we read the data into a _Pandas_ _Dataframe_. This is something you will use very often if you have data in ASCII column files. Get to know this method well. The method has keywords to help describe how to read the column data including the delimter, number of header rows, and which column is the time stamp. If it can parse the time stamp it will convert to Pandas native time type.

# %%
filename = Path('..', 'data', 'sgpmetE13.b1', 'sgpmetE13.00.20191105.150801.raw.dat')
df = pd.read_csv(filename, delimiter=',', header=0, skiprows=[0, 2, 3], parse_dates=[0])

df
# Out:
#              TIMESTAMP  RECORD  batt_volt  PTemp  Pressure_kPa  Temp_C_Avg
# 0  2019-11-05 13:00:00  303333      11.73  6.048         98.78       2.240  \
# 1  2019-11-05 13:01:00  303334      11.72  6.048         98.78       2.299
# 2  2019-11-05 13:02:00  303335      12.02  6.048         98.78       2.309
# 3  2019-11-05 13:03:00  303336      11.70  6.048         98.78       2.331
# 4  2019-11-05 13:04:00  303337      11.71  6.048         98.78       2.334
# 5  2019-11-05 13:05:00  303338      11.73  6.048         98.78       2.346
# 6  2019-11-05 13:06:00  303339      11.72  6.048         98.78       2.325
# 7  2019-11-05 13:07:00  303340      11.71  6.048         98.78       2.248
# 8  2019-11-05 13:08:00  303341      11.70  6.048         98.78       2.196
# 9  2019-11-05 13:09:00  303342      11.73  6.048         98.78       2.146
# 10 2019-11-05 13:10:00  303343      11.71  6.048         98.78       2.102
# 11 2019-11-05 13:11:00  303344      11.73  6.048         98.78       2.087
# 12 2019-11-05 13:12:00  303345      11.71  6.048         98.78       2.155
# 13 2019-11-05 13:13:00  303346      11.72  6.048         98.78       2.215
# 14 2019-11-05 13:14:00  303347      11.72  6.068         98.78       2.273
# 15 2019-11-05 13:15:00  303348      11.73  6.068         98.78       2.339
# 16 2019-11-05 13:16:00  303349      11.72  6.091         98.78       2.429
# 17 2019-11-05 13:17:00  303350      12.00  6.113         98.78       2.506
# 18 2019-11-05 13:18:00  303351      11.71  6.113         98.78       2.544
# 19 2019-11-05 13:19:00  303352      11.72  6.156         98.78       2.610
# 20 2019-11-05 13:20:00  303353      11.70  6.199         98.79       2.712
# 21 2019-11-05 13:21:00  303354      11.71  6.222         98.79       2.821
# 22 2019-11-05 13:22:00  303355      11.71  6.242         98.79       2.896
# 23 2019-11-05 13:23:00  303356      12.02  6.265         98.79       2.975
# 24 2019-11-05 13:24:00  303357      11.71  6.308         98.80       2.990
# 25 2019-11-05 13:25:00  303358      11.71  6.330         98.80       3.054
# 26 2019-11-05 13:26:00  303359      12.00  6.373         98.79       3.134
# 27 2019-11-05 13:27:00  303360      11.71  6.416         98.79       3.185
# 28 2019-11-05 13:28:00  303361      11.70  6.439         98.79       3.239
# 29 2019-11-05 13:29:00  303362      12.02  6.482         98.79       3.292
# 30 2019-11-05 13:30:00  303363      11.70  6.524         98.80       3.314
# 31 2019-11-05 13:31:00  303364      12.01  6.570         98.80       3.326
# 32 2019-11-05 13:32:00  303365      11.72  6.613         98.80       3.316
# 33 2019-11-05 13:33:00  303366      12.02  6.656         98.80       3.317
# 34 2019-11-05 13:34:00  303367      11.72  6.701         98.80       3.328
# 35 2019-11-05 13:35:00  303368      12.02  6.744         98.80       3.334
# 36 2019-11-05 13:36:00  303369      11.71  6.809         98.81       3.346
# 37 2019-11-05 13:37:00  303370      11.72  6.852         98.81       3.371
# 38 2019-11-05 13:38:00  303371      12.01  6.897         98.81       3.405
# 39 2019-11-05 13:39:00  303372      11.71  6.963         98.82       3.433
# 40 2019-11-05 13:40:00  303373      11.71  7.028         98.82       3.443
# 41 2019-11-05 13:41:00  303374      12.01  7.071         98.82       3.461
# 42 2019-11-05 13:42:00  303375      11.71  7.137         98.83       3.492
# 43 2019-11-05 13:43:00  303376      12.01  7.180         98.83       3.541
# 44 2019-11-05 13:44:00  303377      11.69  7.245         98.83       3.590
# 45 2019-11-05 13:45:00  303378      12.02  7.290         98.84       3.615
# 46 2019-11-05 13:46:00  303379      11.71  7.356         98.84       3.629
# 47 2019-11-05 13:47:00  303380      12.00  7.421         98.84       3.627
# 48 2019-11-05 13:48:00  303381      11.71  7.464         98.85       3.637
# 49 2019-11-05 13:49:00  303382      12.03  7.532         98.85       3.686
# 50 2019-11-05 13:50:00  303383      11.72  7.598         98.85       3.752
# 51 2019-11-05 13:51:00  303384      12.01  7.686         98.85       3.806
# 52 2019-11-05 13:52:00  303385      12.01  7.751         98.85       3.856
# 53 2019-11-05 13:53:00  303386      11.72  7.794         98.85       3.895
# 54 2019-11-05 13:54:00  303387      11.71  7.862         98.85       3.934
# 55 2019-11-05 13:55:00  303388      11.71  7.927         98.86       3.953
# 56 2019-11-05 13:56:00  303389      12.03  7.993         98.86       4.006
# 57 2019-11-05 13:57:00  303390      12.01  8.060         98.86       4.075
# 58 2019-11-05 13:58:00  303391      11.73  8.100         98.86       4.120
# 59 2019-11-05 13:59:00  303392      12.02  8.190         98.86       4.162
#
#     Temp_C_Std  RH_Avg  RH_Std  Vap_Pressure_kPa_Avg  ...  PWDa_Code_1hour
# 0        0.029    87.6   0.318                 0.629  ...                0  \
# 1        0.017    87.5   0.144                 0.631  ...                0
# 2        0.016    87.0   0.193                 0.628  ...                0
# 3        0.014    87.1   0.157                 0.629  ...                0
# 4        0.014    86.9   0.110                 0.628  ...                0
# 5        0.012    86.5   0.236                 0.625  ...                0
# 6        0.017    86.4   0.135                 0.624  ...                0
# 7        0.028    86.2   0.213                 0.619  ...                0
# 8        0.014    86.5   0.171                 0.619  ...                0
# 9        0.029    86.7   0.203                 0.618  ...                0
# 10       0.021    87.2   0.110                 0.619  ...                0
# 11       0.018    87.1   0.136                 0.618  ...                0
# 12       0.032    87.6   0.105                 0.625  ...                0
# 13       0.019    87.4   0.242                 0.626  ...                0
# 14       0.029    87.3   0.097                 0.628  ...                0
# 15       0.023    86.9   0.254                 0.628  ...                0
# 16       0.038    86.9   0.155                 0.632  ...                0
# 17       0.017    86.3   0.268                 0.631  ...                0
# 18       0.015    86.1   0.126                 0.632  ...                0
# 19       0.043    86.3   0.085                 0.636  ...                0
# 20       0.028    86.2   0.114                 0.640  ...                0
# 21       0.025    85.5   0.247                 0.639  ...                0
# 22       0.043    85.5   0.124                 0.643  ...                0
# 23       0.015    85.0   0.202                 0.643  ...                0
# 24       0.015    84.6   0.101                 0.640  ...                0
# 25       0.035    84.7   0.101                 0.644  ...                0
# 26       0.029    84.4   0.249                 0.645  ...                0
# 27       0.013    83.8   0.136                 0.643  ...                0
# 28       0.032    84.0   0.117                 0.647  ...                0
# 29       0.014    83.6   0.217                 0.647  ...                0
# 30       0.016    83.3   0.137                 0.645  ...                0
# 31       0.010    83.1   0.316                 0.645  ...                0
# 32       0.013    83.1   0.301                 0.644  ...                0
# 33       0.011    83.2   0.205                 0.645  ...                0
# 34       0.013    83.4   0.206                 0.646  ...                0
# 35       0.014    83.4   0.164                 0.647  ...                0
# 36       0.019    83.2   0.154                 0.646  ...                0
# 37       0.027    83.5   0.103                 0.650  ...                0
# 38       0.021    83.5   0.232                 0.651  ...                0
# 39       0.019    83.4   0.296                 0.652  ...                0
# 40       0.013    84.1   0.120                 0.658  ...                0
# 41       0.011    83.8   0.289                 0.656  ...                0
# 42       0.020    83.7   0.221                 0.656  ...                0
# 43       0.024    83.8   0.258                 0.660  ...                0
# 44       0.018    83.6   0.149                 0.660  ...                0
# 45       0.011    83.7   0.201                 0.662  ...                0
# 46       0.010    83.4   0.223                 0.661  ...                0
# 47       0.008    83.7   0.211                 0.662  ...                0
# 48       0.015    83.7   0.342                 0.663  ...                0
# 49       0.028    84.0   0.144                 0.668  ...                0
# 50       0.023    83.6   0.181                 0.668  ...                0
# 51       0.017    83.9   0.310                 0.673  ...                0
# 52       0.021    83.0   0.161                 0.668  ...                0
# 53       0.023    83.0   0.125                 0.670  ...                0
# 54       0.015    83.1   0.234                 0.672  ...                0
# 55       0.014    83.4   0.204                 0.676  ...                0
# 56       0.028    83.5   0.187                 0.679  ...                0
# 57       0.022    83.1   0.131                 0.679  ...                0
# 58       0.021    82.8   0.089                 0.679  ...                0
# 59       0.019    83.0   0.167                 0.682  ...                0
#
#     PWDa_H2O_Int_Avg_1min  PWDa_Total_H2O_mm  PWDa_Total_Snow_mm  PCP_Rate
# 0                       0              62.31                  14         0  \
# 1                       0              62.31                  14         0
# 2                       0              62.31                  14         0
# 3                       0              62.31                  14         0
# 4                       0              62.31                  14         0
# 5                       0              62.31                  14         0
# 6                       0              62.31                  14         0
# 7                       0              62.31                  14         0
# 8                       0              62.31                  14         0
# 9                       0              62.31                  14         0
# 10                      0              62.31                  14         0
# 11                      0              62.31                  14         0
# 12                      0              62.31                  14         0
# 13                      0              62.31                  14         0
# 14                      0              62.31                  14         0
# 15                      0              62.31                  14         0
# 16                      0              62.31                  14         0
# 17                      0              62.31                  14         0
# 18                      0              62.31                  14         0
# 19                      0              62.31                  14         0
# 20                      0              62.31                  14         0
# 21                      0              62.31                  14         0
# 22                      0              62.31                  14         0
# 23                      0              62.31                  14         0
# 24                      0              62.31                  14         0
# 25                      0              62.31                  14         0
# 26                      0              62.31                  14         0
# 27                      0              62.31                  14         0
# 28                      0              62.31                  14         0
# 29                      0              62.31                  14         0
# 30                      0              62.31                  14         0
# 31                      0              62.31                  14         0
# 32                      0              62.31                  14         0
# 33                      0              62.31                  14         0
# 34                      0              62.31                  14         0
# 35                      0              62.31                  14         0
# 36                      0              62.31                  14         0
# 37                      0              62.31                  14         0
# 38                      0              62.31                  14         0
# 39                      0              62.31                  14         0
# 40                      0              62.31                  14         0
# 41                      0              62.31                  14         0
# 42                      0              62.31                  14         0
# 43                      0              62.31                  14         0
# 44                      0              62.31                  14         0
# 45                      0              62.31                  14         0
# 46                      0              62.31                  14         0
# 47                      0              62.31                  14         0
# 48                      0              62.31                  14         0
# 49                      0              62.31                  14         0
# 50                      0              62.31                  14         0
# 51                      0              62.31                  14         0
# 52                      0              62.31                  14         0
# 53                      0              62.31                  14         0
# 54                      0              62.31                  14         0
# 55                      0              62.31                  14         0
# 56                      0              62.31                  14         0
# 57                      0              62.31                  14         0
# 58                      0              62.31                  14         0
# 59                      0              62.31                  14         0
#
#     WS_Slope  WS_Offset  TBRG_SN  RainCoefA  RainCoefB
# 0      0.098          0      118          0      1.024
# 1      0.098          0      118          0      1.024
# 2      0.098          0      118          0      1.024
# 3      0.098          0      118          0      1.024
# 4      0.098          0      118          0      1.024
# 5      0.098          0      118          0      1.024
# 6      0.098          0      118          0      1.024
# 7      0.098          0      118          0      1.024
# 8      0.098          0      118          0      1.024
# 9      0.098          0      118          0      1.024
# 10     0.098          0      118          0      1.024
# 11     0.098          0      118          0      1.024
# 12     0.098          0      118          0      1.024
# 13     0.098          0      118          0      1.024
# 14     0.098          0      118          0      1.024
# 15     0.098          0      118          0      1.024
# 16     0.098          0      118          0      1.024
# 17     0.098          0      118          0      1.024
# 18     0.098          0      118          0      1.024
# 19     0.098          0      118          0      1.024
# 20     0.098          0      118          0      1.024
# 21     0.098          0      118          0      1.024
# 22     0.098          0      118          0      1.024
# 23     0.098          0      118          0      1.024
# 24     0.098          0      118          0      1.024
# 25     0.098          0      118          0      1.024
# 26     0.098          0      118          0      1.024
# 27     0.098          0      118          0      1.024
# 28     0.098          0      118          0      1.024
# 29     0.098          0      118          0      1.024
# 30     0.098          0      118          0      1.024
# 31     0.098          0      118          0      1.024
# 32     0.098          0      118          0      1.024
# 33     0.098          0      118          0      1.024
# 34     0.098          0      118          0      1.024
# 35     0.098          0      118          0      1.024
# 36     0.098          0      118          0      1.024
# 37     0.098          0      118          0      1.024
# 38     0.098          0      118          0      1.024
# 39     0.098          0      118          0      1.024
# 40     0.098          0      118          0      1.024
# 41     0.098          0      118          0      1.024
# 42     0.098          0      118          0      1.024
# 43     0.098          0      118          0      1.024
# 44     0.098          0      118          0      1.024
# 45     0.098          0      118          0      1.024
# 46     0.098          0      118          0      1.024
# 47     0.098          0      118          0      1.024
# 48     0.098          0      118          0      1.024
# 49     0.098          0      118          0      1.024
# 50     0.098          0      118          0      1.024
# 51     0.098          0      118          0      1.024
# 52     0.098          0      118          0      1.024
# 53     0.098          0      118          0      1.024
# 54     0.098          0      118          0      1.024
# 55     0.098          0      118          0      1.024
# 56     0.098          0      118          0      1.024
# 57     0.098          0      118          0      1.024
# 58     0.098          0      118          0      1.024
# 59     0.098          0      118          0      1.024
#
# [60 rows x 33 columns]

# %% [markdown]
# How many data samples do we have? Can use the Python _len()_ function. Notice it returns the number of rows only.

# %%
len(df)
# Out:
# 60

# %% [markdown]
# Similar to Numpy, can use the _.shape_ and _.size_ methods on the Dataframe to return metadata about size of the Dataframe.

# %%
print(df.size)
print(df.shape)
# Out:
# 1980
# (60, 33)

# %% [markdown]
# Print the first five rows

# %%
df[:5]
# Out:
#             TIMESTAMP  RECORD  batt_volt  PTemp  Pressure_kPa  Temp_C_Avg
# 0 2019-11-05 13:00:00  303333      11.73  6.048         98.78       2.240  \
# 1 2019-11-05 13:01:00  303334      11.72  6.048         98.78       2.299
# 2 2019-11-05 13:02:00  303335      12.02  6.048         98.78       2.309
# 3 2019-11-05 13:03:00  303336      11.70  6.048         98.78       2.331
# 4 2019-11-05 13:04:00  303337      11.71  6.048         98.78       2.334
#
#    Temp_C_Std  RH_Avg  RH_Std  Vap_Pressure_kPa_Avg  ...  PWDa_Code_1hour
# 0       0.029    87.6   0.318                 0.629  ...                0  \
# 1       0.017    87.5   0.144                 0.631  ...                0
# 2       0.016    87.0   0.193                 0.628  ...                0
# 3       0.014    87.1   0.157                 0.629  ...                0
# 4       0.014    86.9   0.110                 0.628  ...                0
#
#    PWDa_H2O_Int_Avg_1min  PWDa_Total_H2O_mm  PWDa_Total_Snow_mm  PCP_Rate
# 0                      0              62.31                  14         0  \
# 1                      0              62.31                  14         0
# 2                      0              62.31                  14         0
# 3                      0              62.31                  14         0
# 4                      0              62.31                  14         0
#
#    WS_Slope  WS_Offset  TBRG_SN  RainCoefA  RainCoefB
# 0     0.098          0      118          0      1.024
# 1     0.098          0      118          0      1.024
# 2     0.098          0      118          0      1.024
# 3     0.098          0      118          0      1.024
# 4     0.098          0      118          0      1.024
#
# [5 rows x 33 columns]

# %% [markdown]
# We can get the names of the columns with .columns method

# %%
df.columns
# Out:
# Index(['TIMESTAMP', 'RECORD', 'batt_volt', 'PTemp', 'Pressure_kPa',
#        'Temp_C_Avg', 'Temp_C_Std', 'RH_Avg', 'RH_Std', 'Vap_Pressure_kPa_Avg',
#        'Vap_Pressure_kPa_Std', 'WS_MS_S_WVT', 'WS_MS_U_WVT', 'WindDir_DU_WVT',
#        'WindDir_SDU_WVT', 'rain_mm_Tot', 'rain_mm_min_corrected', 'PWDa_ID',
#        'PWDa_Alarms', 'PWDa_Vis_Avg_1min', 'PWDa_Vis_Avg_10min',
#        'PWDa_Code_instant', 'PWDa_Code_15min', 'PWDa_Code_1hour',
#        'PWDa_H2O_Int_Avg_1min', 'PWDa_Total_H2O_mm', 'PWDa_Total_Snow_mm',
#        'PCP_Rate', 'WS_Slope', 'WS_Offset', 'TBRG_SN', 'RainCoefA',
#        'RainCoefB'],
#       dtype='object')

# %% [markdown]
# Pandas has a few methods used to inspect the data in the Dataset or Series and present the typical statistical values. Because Pandas plays so well with Jupyter the output is very easy to visualize.

# %%
df.describe()
# Out:
#                            TIMESTAMP         RECORD  batt_volt      PTemp
# count                             60      60.000000   60.00000  60.000000  \
# mean   2019-11-05 13:29:29.999999744  303362.500000   11.80900   6.726183
# min              2019-11-05 13:00:00  303333.000000   11.69000   6.048000
# 25%              2019-11-05 13:14:45  303347.750000   11.71000   6.068000
# 50%              2019-11-05 13:29:30  303362.500000   11.72000   6.503000
# 75%              2019-11-05 13:44:15  303377.250000   12.01000   7.256250
# max              2019-11-05 13:59:00  303392.000000   12.03000   8.190000
# std                              NaN      17.464249    0.14119   0.687847
#
#        Pressure_kPa  Temp_C_Avg  Temp_C_Std     RH_Avg    RH_Std
# count     60.000000   60.000000   60.000000  60.000000  60.00000  \
# mean      98.807833    3.085033    0.020300  84.796667   0.18545
# min       98.780000    2.087000    0.008000  82.800000   0.08500
# 25%       98.780000    2.344250    0.014000  83.400000   0.12975
# 50%       98.800000    3.303000    0.018500  83.950000   0.17600
# 75%       98.832500    3.596250    0.025500  86.425000   0.23250
# max       98.860000    4.162000    0.043000  87.600000   0.34200
# std        0.029000    0.636304    0.008091   1.625743   0.06714
#
#        Vap_Pressure_kPa_Avg  ...  PWDa_Code_1hour  PWDa_H2O_Int_Avg_1min
# count             60.000000  ...             60.0                   60.0  \
# mean               0.646317  ...              0.0                    0.0
# min                0.618000  ...              0.0                    0.0
# 25%                0.630500  ...              0.0                    0.0
# 50%                0.645000  ...              0.0                    0.0
# 75%                0.660250  ...              0.0                    0.0
# max                0.682000  ...              0.0                    0.0
# std                0.018053  ...              0.0                    0.0
#
#        PWDa_Total_H2O_mm  PWDa_Total_Snow_mm  PCP_Rate      WS_Slope
# count       6.000000e+01                60.0      60.0  6.000000e+01  \
# mean        6.231000e+01                14.0       0.0  9.800000e-02
# min         6.231000e+01                14.0       0.0  9.800000e-02
# 25%         6.231000e+01                14.0       0.0  9.800000e-02
# 50%         6.231000e+01                14.0       0.0  9.800000e-02
# 75%         6.231000e+01                14.0       0.0  9.800000e-02
# max         6.231000e+01                14.0       0.0  9.800000e-02
# std         5.015773e-14                 0.0       0.0  8.396941e-17
#
#        WS_Offset  TBRG_SN  RainCoefA     RainCoefB
# count       60.0     60.0       60.0  6.000000e+01
# mean         0.0    118.0        0.0  1.024000e+00
# min          0.0    118.0        0.0  1.024000e+00
# 25%          0.0    118.0        0.0  1.024000e+00
# 50%          0.0    118.0        0.0  1.024000e+00
# 75%          0.0    118.0        0.0  1.024000e+00
# max          0.0    118.0        0.0  1.024000e+00
# std          0.0      0.0        0.0  6.717553e-16
#
# [8 rows x 33 columns]

# %% [markdown]
# Calculate the correlation coefficients of the DataFrame on each Series

# %%
df.corr(numeric_only=True)
# Out:
#                          RECORD  batt_volt     PTemp  Pressure_kPa
# RECORD                 1.000000   0.353105  0.957377      0.944576  \
# batt_volt              0.353105   1.000000  0.342264      0.311581
# PTemp                  0.957377   0.342264  1.000000      0.988704
# Pressure_kPa           0.944576   0.311581  0.988704      1.000000
# Temp_C_Avg             0.974006   0.379203  0.932993      0.914445
# Temp_C_Std            -0.169243  -0.212785 -0.191714     -0.183545
# RH_Avg                -0.891562  -0.347359 -0.794232     -0.765176
# RH_Std                 0.118046   0.313390  0.112635      0.125165
# Vap_Pressure_kPa_Avg   0.964398   0.377488  0.966300      0.956052
# Vap_Pressure_kPa_Std   0.309371   0.091478  0.286586      0.306256
# WS_MS_S_WVT           -0.213800  -0.149424 -0.150390     -0.108980
# WS_MS_U_WVT           -0.226791  -0.153709 -0.163469     -0.121767
# WindDir_DU_WVT        -0.594445  -0.232236 -0.758137     -0.782881
# WindDir_SDU_WVT        0.828063   0.307706  0.781542      0.756315
# rain_mm_Tot                 NaN        NaN       NaN           NaN
# rain_mm_min_corrected       NaN        NaN       NaN           NaN
# PWDa_ID                     NaN        NaN       NaN           NaN
# PWDa_Alarms                 NaN        NaN       NaN           NaN
# PWDa_Vis_Avg_1min           NaN        NaN       NaN           NaN
# PWDa_Vis_Avg_10min          NaN        NaN       NaN           NaN
# PWDa_Code_instant           NaN        NaN       NaN           NaN
# PWDa_Code_15min             NaN        NaN       NaN           NaN
# PWDa_Code_1hour             NaN        NaN       NaN           NaN
# PWDa_H2O_Int_Avg_1min       NaN        NaN       NaN           NaN
# PWDa_Total_H2O_mm           NaN        NaN       NaN           NaN
# PWDa_Total_Snow_mm          NaN        NaN       NaN           NaN
# PCP_Rate                    NaN        NaN       NaN           NaN
# WS_Slope                    NaN        NaN       NaN           NaN
# WS_Offset                   NaN        NaN       NaN           NaN
# TBRG_SN                     NaN        NaN       NaN           NaN
# RainCoefA                   NaN        NaN       NaN           NaN
# RainCoefB                   NaN        NaN       NaN           NaN
#
#                        Temp_C_Avg  Temp_C_Std    RH_Avg    RH_Std
# RECORD                   0.974006   -0.169243 -0.891562  0.118046  \
# batt_volt                0.379203   -0.212785 -0.347359  0.313390
# PTemp                    0.932993   -0.191714 -0.794232  0.112635
# Pressure_kPa             0.914445   -0.183545 -0.765176  0.125165
# Temp_C_Avg               1.000000   -0.213838 -0.941479  0.134751
# Temp_C_Std              -0.213838    1.000000  0.301843 -0.338894
# RH_Avg                  -0.941479    0.301843  1.000000 -0.168619
# RH_Std                   0.134751   -0.338894 -0.168619  1.000000
# Vap_Pressure_kPa_Avg     0.972236   -0.138741 -0.836746  0.101973
# Vap_Pressure_kPa_Std     0.294922   -0.091266 -0.333038  0.558485
# WS_MS_S_WVT             -0.252951    0.082928  0.337484  0.003304
# WS_MS_U_WVT             -0.266202    0.084840  0.348800  0.002782
# WindDir_DU_WVT          -0.559914    0.301636  0.403545 -0.151329
# WindDir_SDU_WVT          0.870709   -0.155074 -0.815390  0.036325
# rain_mm_Tot                   NaN         NaN       NaN       NaN
# rain_mm_min_corrected         NaN         NaN       NaN       NaN
# PWDa_ID                       NaN         NaN       NaN       NaN
# PWDa_Alarms                   NaN         NaN       NaN       NaN
# PWDa_Vis_Avg_1min             NaN         NaN       NaN       NaN
# PWDa_Vis_Avg_10min            NaN         NaN       NaN       NaN
# PWDa_Code_instant             NaN         NaN       NaN       NaN
# PWDa_Code_15min               NaN         NaN       NaN       NaN
# PWDa_Code_1hour               NaN         NaN       NaN       NaN
# PWDa_H2O_Int_Avg_1min         NaN         NaN       NaN       NaN
# PWDa_Total_H2O_mm             NaN         NaN       NaN       NaN
# PWDa_Total_Snow_mm            NaN         NaN       NaN       NaN
# PCP_Rate                      NaN         NaN       NaN       NaN
# WS_Slope                      NaN         NaN       NaN       NaN
# WS_Offset                     NaN         NaN       NaN       NaN
# TBRG_SN                       NaN         NaN       NaN       NaN
# RainCoefA                     NaN         NaN       NaN       NaN
# RainCoefB                     NaN         NaN       NaN       NaN
#
#                        Vap_Pressure_kPa_Avg  Vap_Pressure_kPa_Std  ...
# RECORD                             0.964398              0.309371  ...  \
# batt_volt                          0.377488              0.091478  ...
# PTemp                              0.966300              0.286586  ...
# Pressure_kPa                       0.956052              0.306256  ...
# Temp_C_Avg                         0.972236              0.294922  ...
# Temp_C_Std                        -0.138741             -0.091266  ...
# RH_Avg                            -0.836746             -0.333038  ...
# RH_Std                             0.101973              0.558485  ...
# Vap_Pressure_kPa_Avg               1.000000              0.247242  ...
# Vap_Pressure_kPa_Std               0.247242              1.000000  ...
# WS_MS_S_WVT                       -0.175122             -0.011629  ...
# WS_MS_U_WVT                       -0.188801             -0.013321  ...
# WindDir_DU_WVT                    -0.631384             -0.250849  ...
# WindDir_SDU_WVT                    0.847603              0.114306  ...
# rain_mm_Tot                             NaN                   NaN  ...
# rain_mm_min_corrected                   NaN                   NaN  ...
# PWDa_ID                                 NaN                   NaN  ...
# PWDa_Alarms                             NaN                   NaN  ...
# PWDa_Vis_Avg_1min                       NaN                   NaN  ...
# PWDa_Vis_Avg_10min                      NaN                   NaN  ...
# PWDa_Code_instant                       NaN                   NaN  ...
# PWDa_Code_15min                         NaN                   NaN  ...
# PWDa_Code_1hour                         NaN                   NaN  ...
# PWDa_H2O_Int_Avg_1min                   NaN                   NaN  ...
# PWDa_Total_H2O_mm                       NaN                   NaN  ...
# PWDa_Total_Snow_mm                      NaN                   NaN  ...
# PCP_Rate                                NaN                   NaN  ...
# WS_Slope                                NaN                   NaN  ...
# WS_Offset                               NaN                   NaN  ...
# TBRG_SN                                 NaN                   NaN  ...
# RainCoefA                               NaN                   NaN  ...
# RainCoefB                               NaN                   NaN  ...
#
#                        PWDa_Code_1hour  PWDa_H2O_Int_Avg_1min
# RECORD                             NaN                    NaN  \
# batt_volt                          NaN                    NaN
# PTemp                              NaN                    NaN
# Pressure_kPa                       NaN                    NaN
# Temp_C_Avg                         NaN                    NaN
# Temp_C_Std                         NaN                    NaN
# RH_Avg                             NaN                    NaN
# RH_Std                             NaN                    NaN
# Vap_Pressure_kPa_Avg               NaN                    NaN
# Vap_Pressure_kPa_Std               NaN                    NaN
# WS_MS_S_WVT                        NaN                    NaN
# WS_MS_U_WVT                        NaN                    NaN
# WindDir_DU_WVT                     NaN                    NaN
# WindDir_SDU_WVT                    NaN                    NaN
# rain_mm_Tot                        NaN                    NaN
# rain_mm_min_corrected              NaN                    NaN
# PWDa_ID                            NaN                    NaN
# PWDa_Alarms                        NaN                    NaN
# PWDa_Vis_Avg_1min                  NaN                    NaN
# PWDa_Vis_Avg_10min                 NaN                    NaN
# PWDa_Code_instant                  NaN                    NaN
# PWDa_Code_15min                    NaN                    NaN
# PWDa_Code_1hour                    NaN                    NaN
# PWDa_H2O_Int_Avg_1min              NaN                    NaN
# PWDa_Total_H2O_mm                  NaN                    NaN
# PWDa_Total_Snow_mm                 NaN                    NaN
# PCP_Rate                           NaN                    NaN
# WS_Slope                           NaN                    NaN
# WS_Offset                          NaN                    NaN
# TBRG_SN                            NaN                    NaN
# RainCoefA                          NaN                    NaN
# RainCoefB                          NaN                    NaN
#
#                        PWDa_Total_H2O_mm  PWDa_Total_Snow_mm  PCP_Rate
# RECORD                               NaN                 NaN       NaN  \
# batt_volt                            NaN                 NaN       NaN
# PTemp                                NaN                 NaN       NaN
# Pressure_kPa                         NaN                 NaN       NaN
# Temp_C_Avg                           NaN                 NaN       NaN
# Temp_C_Std                           NaN                 NaN       NaN
# RH_Avg                               NaN                 NaN       NaN
# RH_Std                               NaN                 NaN       NaN
# Vap_Pressure_kPa_Avg                 NaN                 NaN       NaN
# Vap_Pressure_kPa_Std                 NaN                 NaN       NaN
# WS_MS_S_WVT                          NaN                 NaN       NaN
# WS_MS_U_WVT                          NaN                 NaN       NaN
# WindDir_DU_WVT                       NaN                 NaN       NaN
# WindDir_SDU_WVT                      NaN                 NaN       NaN
# rain_mm_Tot                          NaN                 NaN       NaN
# rain_mm_min_corrected                NaN                 NaN       NaN
# PWDa_ID                              NaN                 NaN       NaN
# PWDa_Alarms                          NaN                 NaN       NaN
# PWDa_Vis_Avg_1min                    NaN                 NaN       NaN
# PWDa_Vis_Avg_10min                   NaN                 NaN       NaN
# PWDa_Code_instant                    NaN                 NaN       NaN
# PWDa_Code_15min                      NaN                 NaN       NaN
# PWDa_Code_1hour                      NaN                 NaN       NaN
# PWDa_H2O_Int_Avg_1min                NaN                 NaN       NaN
# PWDa_Total_H2O_mm                    NaN                 NaN       NaN
# PWDa_Total_Snow_mm                   NaN                 NaN       NaN
# PCP_Rate                             NaN                 NaN       NaN
# WS_Slope                             NaN                 NaN       NaN
# WS_Offset                            NaN                 NaN       NaN
# TBRG_SN                              NaN                 NaN       NaN
# RainCoefA                            NaN                 NaN       NaN
# RainCoefB                            NaN                 NaN       NaN
#
#                        WS_Slope  WS_Offset  TBRG_SN  RainCoefA  RainCoefB
# RECORD                      NaN        NaN      NaN        NaN        NaN
# batt_volt                   NaN        NaN      NaN        NaN        NaN
# PTemp                       NaN        NaN      NaN        NaN        NaN
# Pressure_kPa                NaN        NaN      NaN        NaN        NaN
# Temp_C_Avg                  NaN        NaN      NaN        NaN        NaN
# Temp_C_Std                  NaN        NaN      NaN        NaN        NaN
# RH_Avg                      NaN        NaN      NaN        NaN        NaN
# RH_Std                      NaN        NaN      NaN        NaN        NaN
# Vap_Pressure_kPa_Avg        NaN        NaN      NaN        NaN        NaN
# Vap_Pressure_kPa_Std        NaN        NaN      NaN        NaN        NaN
# WS_MS_S_WVT                 NaN        NaN      NaN        NaN        NaN
# WS_MS_U_WVT                 NaN        NaN      NaN        NaN        NaN
# WindDir_DU_WVT              NaN        NaN      NaN        NaN        NaN
# WindDir_SDU_WVT             NaN        NaN      NaN        NaN        NaN
# rain_mm_Tot                 NaN        NaN      NaN        NaN        NaN
# rain_mm_min_corrected       NaN        NaN      NaN        NaN        NaN
# PWDa_ID                     NaN        NaN      NaN        NaN        NaN
# PWDa_Alarms                 NaN        NaN      NaN        NaN        NaN
# PWDa_Vis_Avg_1min           NaN        NaN      NaN        NaN        NaN
# PWDa_Vis_Avg_10min          NaN        NaN      NaN        NaN        NaN
# PWDa_Code_instant           NaN        NaN      NaN        NaN        NaN
# PWDa_Code_15min             NaN        NaN      NaN        NaN        NaN
# PWDa_Code_1hour             NaN        NaN      NaN        NaN        NaN
# PWDa_H2O_Int_Avg_1min       NaN        NaN      NaN        NaN        NaN
# PWDa_Total_H2O_mm           NaN        NaN      NaN        NaN        NaN
# PWDa_Total_Snow_mm          NaN        NaN      NaN        NaN        NaN
# PCP_Rate                    NaN        NaN      NaN        NaN        NaN
# WS_Slope                    NaN        NaN      NaN        NaN        NaN
# WS_Offset                   NaN        NaN      NaN        NaN        NaN
# TBRG_SN                     NaN        NaN      NaN        NaN        NaN
# RainCoefA                   NaN        NaN      NaN        NaN        NaN
# RainCoefB                   NaN        NaN      NaN        NaN        NaN
#
# [32 rows x 32 columns]

# %% [markdown]
# Calculate the covariance coefficients of the DataFrame on each Series

# %%
df.cov(numeric_only=True)
# Out:
#                            RECORD     batt_volt         PTemp  Pressure_kPa
# RECORD                 305.000000  8.706780e-01  1.150070e+01  4.783898e-01  \
# batt_volt                0.870678  1.993458e-02  3.323968e-02  1.275763e-03
# PTemp                   11.500703  3.323968e-02  4.731330e-01  1.972210e-02
# Pressure_kPa             0.478390  1.275763e-03  1.972210e-02  8.409887e-04
# Temp_C_Avg              10.823712  3.406749e-02  4.083522e-01  1.687397e-02
# Temp_C_Std              -0.023915 -2.430847e-04 -1.066988e-03 -4.306780e-05
# RH_Avg                 -25.313559 -7.973220e-02 -8.881587e-01 -3.607514e-02
# RH_Std                   0.138415  2.970797e-03  5.201730e-03  2.437034e-04
# Vap_Pressure_kPa_Avg     0.304059  9.621864e-04  1.199930e-02  5.005282e-04
# Vap_Pressure_kPa_Std     0.003212  7.677966e-06  1.171856e-04  5.279661e-06
# WS_MS_S_WVT             -0.574881 -3.248203e-03 -1.592685e-02 -4.865876e-04
# WS_MS_U_WVT             -0.613347 -3.360729e-03 -1.741236e-02 -5.468333e-04
# WindDir_DU_WVT         -61.793593 -1.951704e-01 -3.103993e+00 -1.351363e-01
# WindDir_SDU_WVT         13.576271  4.078553e-02  5.046742e-01  2.059039e-02
# rain_mm_Tot              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# rain_mm_min_corrected    0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_ID                  0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Alarms              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Vis_Avg_1min        0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Vis_Avg_10min       0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Code_instant        0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Code_15min          0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Code_1hour          0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_H2O_Int_Avg_1min    0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Total_H2O_mm        0.000000  7.059637e-30 -5.134281e-30  9.241706e-29
# PWDa_Total_Snow_mm       0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# PCP_Rate                 0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# WS_Slope                 0.000000  1.378835e-32 -1.002789e-32  1.805021e-31
# WS_Offset                0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# TBRG_SN                  0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# RainCoefA                0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# RainCoefB                0.000000  0.000000e+00  0.000000e+00  0.000000e+00
#
#                          Temp_C_Avg    Temp_C_Std        RH_Avg        RH_Std
# RECORD                 1.082371e+01 -2.391525e-02 -2.531356e+01  1.384153e-01  \
# batt_volt              3.406749e-02 -2.430847e-04 -7.973220e-02  2.970797e-03
# PTemp                  4.083522e-01 -1.066988e-03 -8.881587e-01  5.201730e-03
# Pressure_kPa           1.687397e-02 -4.306780e-05 -3.607514e-02  2.437034e-04
# Temp_C_Avg             4.048831e-01 -1.100942e-03 -9.739287e-01  5.756815e-03
# Temp_C_Std            -1.100942e-03  6.546780e-05  3.970508e-03 -1.841034e-04
# RH_Avg                -9.739287e-01  3.970508e-03  2.643040e+00 -1.840525e-02
# RH_Std                 5.756815e-03 -1.841034e-04 -1.840525e-02  4.507845e-03
# Vap_Pressure_kPa_Avg   1.116835e-02 -2.026610e-05 -2.455825e-02  1.236008e-04
# Vap_Pressure_kPa_Std   1.115576e-04 -4.389831e-07 -3.218644e-04  2.229068e-05
# WS_MS_S_WVT           -2.478115e-02  1.033085e-04  8.447435e-02  3.414915e-05
# WS_MS_U_WVT           -2.623050e-02  1.063034e-04  8.781282e-02  2.892119e-05
# WindDir_DU_WVT        -2.120645e+00  1.452709e-02  3.905039e+00 -6.047659e-02
# WindDir_SDU_WVT        5.201213e-01 -1.177929e-03 -1.244469e+00  2.289615e-03
# rain_mm_Tot            0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# rain_mm_min_corrected  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_ID                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Alarms            0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Vis_Avg_1min      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Vis_Avg_10min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Code_instant      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Code_15min        0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Code_1hour        0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_H2O_Int_Avg_1min  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PWDa_Total_H2O_mm     -1.176606e-30  7.938749e-33 -1.711427e-30 -2.674105e-32
# PWDa_Total_Snow_mm     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PCP_Rate               0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# WS_Slope              -2.298059e-33  1.550537e-35 -3.342631e-33 -5.222861e-35
# WS_Offset              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TBRG_SN                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# RainCoefA              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# RainCoefB              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                        Vap_Pressure_kPa_Avg  Vap_Pressure_kPa_Std  ...
# RECORD                         3.040593e-01          3.211864e-03  ...  \
# batt_volt                      9.621864e-04          7.677966e-06  ...
# PTemp                          1.199930e-02          1.171856e-04  ...
# Pressure_kPa                   5.005282e-04          5.279661e-06  ...
# Temp_C_Avg                     1.116835e-02          1.115576e-04  ...
# Temp_C_Std                    -2.026610e-05         -4.389831e-07  ...
# RH_Avg                        -2.455825e-02         -3.218644e-04  ...
# RH_Std                         1.236008e-04          2.229068e-05  ...
# Vap_Pressure_kPa_Avg           3.259150e-04          2.653390e-06  ...
# Vap_Pressure_kPa_Std           2.653390e-06          3.533898e-07  ...
# WS_MS_S_WVT                   -4.867582e-04         -1.064407e-06  ...
# WS_MS_U_WVT                   -5.278201e-04         -1.226271e-06  ...
# WindDir_DU_WVT                -6.784650e-02         -8.876085e-04  ...
# WindDir_SDU_WVT                1.436521e-02          6.379153e-05  ...
# rain_mm_Tot                    0.000000e+00          0.000000e+00  ...
# rain_mm_min_corrected          0.000000e+00          0.000000e+00  ...
# PWDa_ID                        0.000000e+00          0.000000e+00  ...
# PWDa_Alarms                    0.000000e+00          0.000000e+00  ...
# PWDa_Vis_Avg_1min              0.000000e+00          0.000000e+00  ...
# PWDa_Vis_Avg_10min             0.000000e+00          0.000000e+00  ...
# PWDa_Code_instant              0.000000e+00          0.000000e+00  ...
# PWDa_Code_15min                0.000000e+00          0.000000e+00  ...
# PWDa_Code_1hour                0.000000e+00          0.000000e+00  ...
# PWDa_H2O_Int_Avg_1min          0.000000e+00          0.000000e+00  ...
# PWDa_Total_H2O_mm             -1.350423e-30         -5.222861e-35  ...
# PWDa_Total_Snow_mm             0.000000e+00          0.000000e+00  ...
# PCP_Rate                       0.000000e+00          0.000000e+00  ...
# WS_Slope                      -2.637545e-33         -1.020090e-37  ...
# WS_Offset                      0.000000e+00          0.000000e+00  ...
# TBRG_SN                        0.000000e+00          0.000000e+00  ...
# RainCoefA                      0.000000e+00          0.000000e+00  ...
# RainCoefB                      0.000000e+00          0.000000e+00  ...
#
#                        PWDa_Code_1hour  PWDa_H2O_Int_Avg_1min
# RECORD                             0.0                    0.0  \
# batt_volt                          0.0                    0.0
# PTemp                              0.0                    0.0
# Pressure_kPa                       0.0                    0.0
# Temp_C_Avg                         0.0                    0.0
# Temp_C_Std                         0.0                    0.0
# RH_Avg                             0.0                    0.0
# RH_Std                             0.0                    0.0
# Vap_Pressure_kPa_Avg               0.0                    0.0
# Vap_Pressure_kPa_Std               0.0                    0.0
# WS_MS_S_WVT                        0.0                    0.0
# WS_MS_U_WVT                        0.0                    0.0
# WindDir_DU_WVT                     0.0                    0.0
# WindDir_SDU_WVT                    0.0                    0.0
# rain_mm_Tot                        0.0                    0.0
# rain_mm_min_corrected              0.0                    0.0
# PWDa_ID                            0.0                    0.0
# PWDa_Alarms                        0.0                    0.0
# PWDa_Vis_Avg_1min                  0.0                    0.0
# PWDa_Vis_Avg_10min                 0.0                    0.0
# PWDa_Code_instant                  0.0                    0.0
# PWDa_Code_15min                    0.0                    0.0
# PWDa_Code_1hour                    0.0                    0.0
# PWDa_H2O_Int_Avg_1min              0.0                    0.0
# PWDa_Total_H2O_mm                  0.0                    0.0
# PWDa_Total_Snow_mm                 0.0                    0.0
# PCP_Rate                           0.0                    0.0
# WS_Slope                           0.0                    0.0
# WS_Offset                          0.0                    0.0
# TBRG_SN                            0.0                    0.0
# RainCoefA                          0.0                    0.0
# RainCoefB                          0.0                    0.0
#
#                        PWDa_Total_H2O_mm  PWDa_Total_Snow_mm  PCP_Rate
# RECORD                      0.000000e+00                 0.0       0.0  \
# batt_volt                   7.059637e-30                 0.0       0.0
# PTemp                      -5.134281e-30                 0.0       0.0
# Pressure_kPa                9.241706e-29                 0.0       0.0
# Temp_C_Avg                 -1.176606e-30                 0.0       0.0
# Temp_C_Std                  7.938749e-33                 0.0       0.0
# RH_Avg                     -1.711427e-30                 0.0       0.0
# RH_Std                     -2.674105e-32                 0.0       0.0
# Vap_Pressure_kPa_Avg       -1.350423e-30                 0.0       0.0
# Vap_Pressure_kPa_Std       -5.222861e-35                 0.0       0.0
# WS_MS_S_WVT                 5.348210e-32                 0.0       0.0
# WS_MS_U_WVT                -7.594458e-30                 0.0       0.0
# WindDir_DU_WVT              2.139284e-31                 0.0       0.0
# WindDir_SDU_WVT            -3.743747e-30                 0.0       0.0
# rain_mm_Tot                 0.000000e+00                 0.0       0.0
# rain_mm_min_corrected       0.000000e+00                 0.0       0.0
# PWDa_ID                     0.000000e+00                 0.0       0.0
# PWDa_Alarms                 0.000000e+00                 0.0       0.0
# PWDa_Vis_Avg_1min           0.000000e+00                 0.0       0.0
# PWDa_Vis_Avg_10min          0.000000e+00                 0.0       0.0
# PWDa_Code_instant           0.000000e+00                 0.0       0.0
# PWDa_Code_15min             0.000000e+00                 0.0       0.0
# PWDa_Code_1hour             0.000000e+00                 0.0       0.0
# PWDa_H2O_Int_Avg_1min       0.000000e+00                 0.0       0.0
# PWDa_Total_H2O_mm           5.134281e-29                 0.0       0.0
# PWDa_Total_Snow_mm          0.000000e+00                 0.0       0.0
# PCP_Rate                    0.000000e+00                 0.0       0.0
# WS_Slope                    1.002789e-31                 0.0       0.0
# WS_Offset                   0.000000e+00                 0.0       0.0
# TBRG_SN                     0.000000e+00                 0.0       0.0
# RainCoefA                   0.000000e+00                 0.0       0.0
# RainCoefB                   0.000000e+00                 0.0       0.0
#
#                            WS_Slope  WS_Offset  TBRG_SN  RainCoefA  RainCoefB
# RECORD                 0.000000e+00        0.0      0.0        0.0        0.0
# batt_volt              1.378835e-32        0.0      0.0        0.0        0.0
# PTemp                 -1.002789e-32        0.0      0.0        0.0        0.0
# Pressure_kPa           1.805021e-31        0.0      0.0        0.0        0.0
# Temp_C_Avg            -2.298059e-33        0.0      0.0        0.0        0.0
# Temp_C_Std             1.550537e-35        0.0      0.0        0.0        0.0
# RH_Avg                -3.342631e-33        0.0      0.0        0.0        0.0
# RH_Std                -5.222861e-35        0.0      0.0        0.0        0.0
# Vap_Pressure_kPa_Avg  -2.637545e-33        0.0      0.0        0.0        0.0
# Vap_Pressure_kPa_Std  -1.020090e-37        0.0      0.0        0.0        0.0
# WS_MS_S_WVT            1.044572e-34        0.0      0.0        0.0        0.0
# WS_MS_U_WVT           -1.483292e-32        0.0      0.0        0.0        0.0
# WindDir_DU_WVT         4.178289e-34        0.0      0.0        0.0        0.0
# WindDir_SDU_WVT       -7.312005e-33        0.0      0.0        0.0        0.0
# rain_mm_Tot            0.000000e+00        0.0      0.0        0.0        0.0
# rain_mm_min_corrected  0.000000e+00        0.0      0.0        0.0        0.0
# PWDa_ID                0.000000e+00        0.0      0.0        0.0        0.0
# PWDa_Alarms            0.000000e+00        0.0      0.0        0.0        0.0
# PWDa_Vis_Avg_1min      0.000000e+00        0.0      0.0        0.0        0.0
# PWDa_Vis_Avg_10min     0.000000e+00        0.0      0.0        0.0        0.0
# PWDa_Code_instant      0.000000e+00        0.0      0.0        0.0        0.0
# PWDa_Code_15min        0.000000e+00        0.0      0.0        0.0        0.0
# PWDa_Code_1hour        0.000000e+00        0.0      0.0        0.0        0.0
# PWDa_H2O_Int_Avg_1min  0.000000e+00        0.0      0.0        0.0        0.0
# PWDa_Total_H2O_mm      1.002789e-31        0.0      0.0        0.0        0.0
# PWDa_Total_Snow_mm     0.000000e+00        0.0      0.0        0.0        0.0
# PCP_Rate               0.000000e+00        0.0      0.0        0.0        0.0
# WS_Slope               1.958573e-34        0.0      0.0        0.0        0.0
# WS_Offset              0.000000e+00        0.0      0.0        0.0        0.0
# TBRG_SN                0.000000e+00        0.0      0.0        0.0        0.0
# RainCoefA              0.000000e+00        0.0      0.0        0.0        0.0
# RainCoefB              0.000000e+00        0.0      0.0        0.0        0.0
#
# [32 rows x 32 columns]

# %% [markdown]
# What type is the time column data? Notice that Pandas has a new data type of time specific to Pandas. This is very similar to Datetime datetime and Numpy datetime64, but is technically different.

# %%
print(type(df['TIMESTAMP'][0]))
print(type(df['PTemp'][0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'numpy.float64'>

# %% [markdown]
# Get the pressure Series from the DataFrame and sum it up to one value or calcualte the mean.

# %%
print(df['Pressure_kPa'].sum())
print(df['Pressure_kPa'].mean())
# Out:
# 5928.469999999999
# 98.80783333333332

# %% [markdown]
# Get the pressure Series from the DataFrame and use a special method to summarize the values in the Series using what Pandas thing is most helpful.

# %%
df['RH_Avg'].describe()
# Out:
# count    60.000000
# mean     84.796667
# std       1.625743
# min      82.800000
# 25%      83.400000
# 50%      83.950000
# 75%      86.425000
# max      87.600000
# Name: RH_Avg, dtype: float64

# %% [markdown]
# Extract the RH series from the DataFrame. This is a copy of the Series in the DataFrame so changing the values will not change the values in the DataFrame.

# %%
rh = df['RH_Avg']
type(rh)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Calculate a rolling mean over the Series using 10 points. Notice the first 8 values are NaN. There is a default number of values to use to calculate a value. Else it is set to NaN.

# %%
rh_rolling_mean = rh.rolling(10).mean()
rh_rolling_mean
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9     86.84
# 10    86.80
# 11    86.76
# 12    86.82
# 13    86.85
# 14    86.89
# 15    86.93
# 16    86.98
# 17    86.99
# 18    86.95
# 19    86.91
# 20    86.81
# 21    86.65
# 22    86.44
# 23    86.20
# 24    85.93
# 25    85.71
# 26    85.46
# 27    85.21
# 28    85.00
# 29    84.73
# 30    84.44
# 31    84.20
# 32    83.96
# 33    83.78
# 34    83.66
# 35    83.53
# 36    83.41
# 37    83.38
# 38    83.33
# 39    83.31
# 40    83.39
# 41    83.46
# 42    83.52
# 43    83.58
# 44    83.60
# 45    83.63
# 46    83.65
# 47    83.67
# 48    83.69
# 49    83.75
# 50    83.70
# 51    83.71
# 52    83.64
# 53    83.56
# 54    83.51
# 55    83.48
# 56    83.49
# 57    83.43
# 58    83.34
# 59    83.24
# Name: RH_Avg, dtype: float64

# %% [markdown]
# By specifically stating the minimum number of points to use when calculating the mean we force it to not fill in so many NaNs. There is at least one value to use in the rollig window so not NaNs. What happens when you change min_periods to a larger number?

# %%
rh_rolling_mean = rh.rolling(10, min_periods=1).mean()
rh_rolling_mean
# Out:
# 0     87.600000
# 1     87.550000
# 2     87.366667
# 3     87.300000
# 4     87.220000
# 5     87.100000
# 6     87.000000
# 7     86.900000
# 8     86.855556
# 9     86.840000
# 10    86.800000
# 11    86.760000
# 12    86.820000
# 13    86.850000
# 14    86.890000
# 15    86.930000
# 16    86.980000
# 17    86.990000
# 18    86.950000
# 19    86.910000
# 20    86.810000
# 21    86.650000
# 22    86.440000
# 23    86.200000
# 24    85.930000
# 25    85.710000
# 26    85.460000
# 27    85.210000
# 28    85.000000
# 29    84.730000
# 30    84.440000
# 31    84.200000
# 32    83.960000
# 33    83.780000
# 34    83.660000
# 35    83.530000
# 36    83.410000
# 37    83.380000
# 38    83.330000
# 39    83.310000
# 40    83.390000
# 41    83.460000
# 42    83.520000
# 43    83.580000
# 44    83.600000
# 45    83.630000
# 46    83.650000
# 47    83.670000
# 48    83.690000
# 49    83.750000
# 50    83.700000
# 51    83.710000
# 52    83.640000
# 53    83.560000
# 54    83.510000
# 55    83.480000
# 56    83.490000
# 57    83.430000
# 58    83.340000
# 59    83.240000
# Name: RH_Avg, dtype: float64

# %% [markdown]
# Set a range of values in our extracted data to NaN to represent missing data.

# %%
rh = pd.Series(rh)
rh.iloc[20: 30] = np.nan

# %% [markdown]
# Calculate a rolling mean.

# %%
rh_rolling_mean = rh.rolling(10, min_periods=2).mean()
rh_rolling_mean
# Out:
# 0           NaN
# 1     87.550000
# 2     87.366667
# 3     87.300000
# 4     87.220000
# 5     87.100000
# 6     87.000000
# 7     86.900000
# 8     86.855556
# 9     86.840000
# 10    86.800000
# 11    86.760000
# 12    86.820000
# 13    86.850000
# 14    86.890000
# 15    86.930000
# 16    86.980000
# 17    86.990000
# 18    86.950000
# 19    86.910000
# 20    86.877778
# 21    86.850000
# 22    86.742857
# 23    86.633333
# 24    86.500000
# 25    86.400000
# 26    86.233333
# 27    86.200000
# 28          NaN
# 29          NaN
# 30          NaN
# 31    83.200000
# 32    83.166667
# 33    83.175000
# 34    83.220000
# 35    83.250000
# 36    83.242857
# 37    83.275000
# 38    83.300000
# 39    83.310000
# 40    83.390000
# 41    83.460000
# 42    83.520000
# 43    83.580000
# 44    83.600000
# 45    83.630000
# 46    83.650000
# 47    83.670000
# 48    83.690000
# 49    83.750000
# 50    83.700000
# 51    83.710000
# 52    83.640000
# 53    83.560000
# 54    83.510000
# 55    83.480000
# 56    83.490000
# 57    83.430000
# 58    83.340000
# 59    83.240000
# Name: RH_Avg, dtype: float64
